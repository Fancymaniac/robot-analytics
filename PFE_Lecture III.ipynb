# %%
x, y, z = 1, 'b' ,3.14 # No char datatype in python

print(type(x))
print(type(y)) # type() function is used to know the type of the variable
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# Find if o/p is Even or Odd through boolean

# %%
x = 1
is_even = (x % 2 == 0)
print(is_even)

y = 10
is_even = (y % 6 == 4)
print(is_even)
# Out:
# False
# True

# %% [markdown]
# Math operations

# %%
# arithmetic operators = +,-,*,/
# % : Modulus will give the remainder when dividing
# ** : to Exponentiate the value x**y is similar to x^y
# // : Divides the 2 numbers and returns the largest integer quotient
# pow() : function is used to perform x^y
# math.pow() : similar to pow() but returns a floating point value

# %%
# incrementing and Decrementing
a = 10
print(a)
a += 5 # a = a + 5
print(a)
a -= 3 # a = a - 3
print(a)
# Out:
# 10
# 15
# 12

# %%
import math

# Square root and Logarithms
sqrt_16 = math.sqrt(18)
print(sqrt_16)

log_1000 = math.log10(1650)
print(log_1000)
# Out:
# 4.242640687119285
# 3.2174839442139063

# %%
# Average of 3 numbers
a,b,c= input(),input(),input() # 'input()' function is used to get the user input
avg = (int(a)+int(b)+int(c))/3
print(int(avg))
# Out:
# 18

# %%
# Celcius to Farenheit
c = int(input())
f = (c * 9/5) + 32
print(f)
# Out:
# 192
# 377.6

# %%
# perimeter of a double bed in inch
l = int(input())
b = int(input())
p = 2 * (l + b)
print(p)
# Out:
# 15
# 16
# 62

# %%
import math
print(" Input the x Coordinates one after the other")
x_1 , x_2  = input(),input()
print(" Input the y Coordinates one after the other")
y_1, y_2 = input(),input()

d = math.sqrt(math.pow((int(x_2) - int(x_1)),2) + (int(y_2) - int(y_1))**2)
print(d)
# Out:
#  Input the x Coordinates one after the other
# -1
# -2
#  Input the y Coordinates one after the other
# 9
# 8
# 1.4142135623730951
